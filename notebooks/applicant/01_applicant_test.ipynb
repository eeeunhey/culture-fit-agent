# %% [markdown]
# # 지원자(Applicant) 분석 및 프롬프트 실험
#
# 이 노트북에서는 지원자 이력서/자기소개서 분석, 성향 파악, 컬처핏 매칭 프롬프트를 독립적으로 테스트합니다.

# %%
import sys
from pathlib import Path

# 프로젝트 루트 경로를 sys.path에 등록하여 src 모듈 import 가능하게 설정
project_root = Path("../../").resolve()
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print("Project root added:", project_root)

# %%
# 샘플 이력서 데이터 확인
resume_path = Path("./sample_resume.txt")
if resume_path.exists():
    with open(resume_path, "r", encoding="utf-8") as f:
        resume_text = f.read()
    print("=== Loaded Resume ===")
    print(resume_text)
else:
    print("sample_resume.txt 파일이 존재하지 않습니다.")

# %% [markdown]
# ## 지원자 분석 로직 및 프롬프트 실험 영역
# 아래 셀에서 지원자 성향/스킬셋을 추출하고 컬처핏 점수를 평가하는 로직을 테스트하세요.

# %%
# TODO: 지원자 성향 / 역량 추출 함수 테스트
def extract_applicant_profile(resume_content: str):
    # 여기에 LLM 호출 또는 파싱 로직 작성
    return {
        "applicant_traits": ["투명한 소통", "데이터 기반", "TDD 지향"],
        "tech_stack": ["Python", "FastAPI", "PostgreSQL"]
    }

result = extract_applicant_profile(resume_text if 'resume_text' in locals() else "")
print("지원자 분석 결과:", result)
