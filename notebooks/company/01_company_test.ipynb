# %% [markdown]
# # 기업(Company) 분석 및 프롬프트 실험
#
# 이 노트북에서는 채용공고(JD), 인재상, 조직문화 분석 프롬프트와 노드 로직을 독립적으로 테스트합니다.

# %%
import sys
from pathlib import Path

# 프로젝트 루트 경로를 sys.path에 등록하여 src 모듈 import 가능하게 설정
project_root = Path("../../").resolve()
if str(project_root) not in sys.path:
    sys.path.append(str(project_root))

print("Project root added:", project_root)

# %%
# 샘플 JD 데이터 확인
jd_path = Path("./sample_jd.txt")
if jd_path.exists():
    with open(jd_path, "r", encoding="utf-8") as f:
        jd_text = f.read()
    print("=== Loaded JD ===")
    print(jd_text)
else:
    print("sample_jd.txt 파일이 존재하지 않습니다.")

# %% [markdown]
# ## 기업 분석 로직 및 프롬프트 실험 영역
# 아래 셀에서 LangChain / LangGraph 노드에 들어갈 프롬프트와 함수를 자유롭게 작성하고 테스트하세요.

# %%
# TODO: 기업 문화 / 인재상 추출 함수 테스트
def extract_company_culture(jd_content: str):
    # 여기에 LLM 호출 또는 규칙 기반 파싱 로직 작성
    return {
        "culture_keywords": ["수평적 소통", "데이터 기반", "도전 장려"],
        "requirements": ["Python", "MSA", "고가용성"]
    }

result = extract_company_culture(jd_text if 'jd_text' in locals() else "")
print("기업 분석 결과:", result)
